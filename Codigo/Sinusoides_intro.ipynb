# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.arange(-0.005, 0.005, 0.0001)
x = 10 * np.cos(2 * np.pi * 440 * t + 0.4 * np.pi)
plt.plot(t,x)

# %%
from IPython.display import Audio, display
display(Audio(data = x, rate = 1/0.0001)) #inverso do incremento no que toca ao rate (ver 't')
# Out:
#                 <audio  controls="controls" >
#                     <source src="..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
